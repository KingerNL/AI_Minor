# %% [markdown]
# # Deep Learning - Agent
#
# ### Van: Mart Veldkamp

# %% [markdown]
# Ik deze notebook ga ik behandelelen hoe je een computer kan trainen om een rubics cube op te lossen door middel van Q-Learning. Deze notebook is afgeleid uit een les uit Deep Learning, en is gemaakt door Aashrey Anand. Dit is zijn [github](https://github.com/AashrayAnand/rubiks-cube-reinforcement-learning).
#
# Daarnaast wou ik nog wat vertellen over hoe het in elkaar zit. Om dit probleem op te lossen is er gebruik gemaakt van iets genaamd Q-learning, dit is een erg krachtige reinforcement learning techniek, met daarnaast het gebruik van een patroon herkenning database. Om een rubiks cube die bijna klaar is te beoordelen (met een limiet aantal zetten). Dit project ging er vanuit dat deze rubiks cube alleen maar 180 graden side turns kon doen. Omdat dit minder process tijd kost voor het factorizeren van elk mogelijke move. Dit project probeert ook in een *n* aantal moves de oplossing te vinden. Als dit niet lukt binnen *n*, zal er gekeken worden naar de qualiteit van de cube om zo te bepalen hoe goed het is gelukt.

# %% [markdown]
# # 1. Library's laden

# %% [markdown]
# Omdat alles eigenlijk zelf is geprogrammeerd gebruik je weinig library's, je import alleen random. Wat nodig is voor een random waarde meegeven. En time, om te timen hoe lang hij erover doet. Ten slot refereer je naar puzzle.py, waar je functies vanuit roept. **Verwijder daarom ook niet dit bestandje**, anders werkt het niet meer.

# %%
import random, time
from puzzle import State, move, num_solved_sides, num_pieces_correct_side, shuffle, n_move_state, one_move_state

# %% [markdown]
# Q-learning is een manier-algoritme waardoor we nieuwe waardes kunnen bepalen, wat "betere" waardes zijn, voor het model. Het lijkt best erg op Backpropogation, alleen zit er nu nog iets extra's bij genaamd "Temporal difference". Wat dit is, is eigenlijk alles wat je nodig hebt voor het gebruiken van Reinforcement Learning. Het neemt naast je oude waardes en de learning rate; de beloning, discount factor en "estimate of optimal future value" mee.
#
# En als we dit loslaten op ons probleem, met wat code. Krijgen we een erg mooi resultaat. Met een computer wat sneller een Rubiks Cube kan oplossen dan elk mens op de aarde.

# %%
ALPHA = 0.6

    # q-values key = (state, action) => value = (q-value, update_count)
class Agent:

    # initialize agent, can be passed a dictionary of Q-Values
    # if it already exists, and a cube, otherwise, initializes new
    # cube if not provided one
    def __init__(self, QValues=None, cube=None):
        self.visited = []
        self.visit_count = {}
        self.revisits = 0
        # maps a state action pair to a Q-Value, and an update count for that Q-Value
        self.QV = QValues if QValues is not None else {}
        # maps a state to a list of rewards for executing each possible outcome
        # can index list of rewards using directional class constants
        self.R = {}
        # create or store initial cube state, and store list of actions
        self.start_state = cube if cube is not None else n_move_state(n=6) 
        print(self.start_state)
        # shuffle initially solved starting state, executing 5 random moves
        # self.start_state = shuffle(self.start_state)
        # store the current state
        self.curr_state = self.start_state
        self.prev_state = None
        self.second_last_action = None
        self.actions = self.start_state.actions
        # pattern lists, used to associate weights with nodes
        # that are closer to the goal state
        self.one_away = []
        self.two_away = []
        self.three_away = []
        self.four_away = []
        self.five_away = []
        self.six_away = []
        self.last_action = None
        self.move = {"front": 0, "back": 0, "left": 0, "right": 0, "top": 0, "bottom": 0}


    def register_patterns(self):
        s = State()
        # get list of goal successors
        for action in self.actions:
            s_ = move(s, action)
            self.one_away.append(s_)
            for action_ in self.actions:
                self.QV[(s_.__hash__(), action_)] = -10 if action_ != action else 10
        # get list of successors of goal successors
        for s in self.one_away:
            for action in self.actions:
                s_ = move(s, action)
                self.two_away.append(s_)
                for action_ in self.actions:
                    self.QV[(s_.__hash__(), action_)] = -6 if action_ != action else 6
        # get list of successors of successors of goal successors
        for s in self.two_away:
            for action in self.actions:
                s_ = move(s, action)
                self.three_away.append(s_)
                for action_ in self.actions:
                    self.QV[(s_.__hash__(), action_)] = -5 if action_ != action else 5
        
        for s in self.three_away:
            for action in self.actions:
                s_ = move(s, action)
                self.four_away.append(s_)
                for action_ in self.actions:
                    self.QV[(s_.__hash__(), action_)] = -4 if action_ != action else 4

        for s in self.four_away:
            for action in self.actions:
                s_ = move(s, action)
                self.five_away.append(s_)
                for action_ in self.actions:
                    self.QV[(s_.__hash__(), action_)] = -3 if action_ != action else 3
        
        for s in self.five_away:
            for action in self.actions:
                s_ = move(s, action)
                self.six_away.append(s_)
                for action_ in self.actions:
                    self.QV[(s_.__hash__(), action_)] = -1 if action_ != action else 1
            
    # explore
    def QLearn(self, discount=0.99, episodes=10, epsilon=0.9):
        # execute q learning for specified number of episodes
        self.curr_state = self.curr_state#six_move_state()
        for i in range(episodes):
            print("=====EPISODE "+str(i)+"=====")
            print("====CURR STATE========")
            print("======================")
            # initialize values in Q-State dictionary for 
            # any state action pairs including current state
            # that are null
            saved_rewards = self.curr_state.__hash__() in self.R.keys()
            if not saved_rewards:
                self.R[self.curr_state.__hash__()] = []
            if not self.curr_state.__hash__ in self.visit_count:
                self.visit_count[self.curr_state.__hash__()] = 1
            else:
                self.visit_count[self.curr_state.__hash__()] += 1
            vc = self.visit_count[self.curr_state.__hash__()]
            # initialize Q-Values of 0 for all state action pairs
            # for the given, state, if they do not exist
            for action in self.actions:
                if not (self.curr_state.__hash__(), action) in self.QV.keys():
                    self.QV[(self.curr_state.__hash__(), action)] = 0
                else:
                    self.revisits += 1
                    break
                if not saved_rewards:
                    self.R[self.curr_state.__hash__()].append(self.reward(self.curr_state, action))
            if 100 in self.R[self.curr_state.__hash__()]:
                print("REACHED GOAL, END QLEARN ITERATION")
                return
            follow_policy = random.uniform(0,1.0)
            print("random value generated is " + str(follow_policy))
            # if random number is > epsilon, we must select best move
            # by the highest q-value
            if follow_policy > epsilon:
                print("FOLLOWING POLICY")
                for action in self.actions:
                    print("q value for action " + action + " from curr state is " + str(self.QV[(self.curr_state.__hash__(), action)]))
                best_action = None
                best_QV = -100000000
                for action in self.actions:
                    if self.QV[(self.curr_state.__hash__(), action)] > best_QV and action != self.last_action and action != self.second_last_action:
                        best_action = action
                        best_QV = self.QV[(self.curr_state.__hash__(), action)]
                if best_QV == 0:
                    best_action = random.choice(self.actions)
                    while best_action == self.last_action:
                        best_action = random.choice(self.actions)
                print("actions chosen = " + best_action)
                self.move[best_action] = self.move[best_action] + 1
                # update Q-Value for current state and action chosen based on the current policy, by taking original Q-value, and adding
                # alpha times the reward value of the new state plus the discounted max_reward of executing every possible
                # action on the new state, minus the original Q-Value
                #reward = self.reward(self.curr_state, best_action)
                #max_reward = self.max_reward(self.curr_state, best_action)
                #self.QV[(self.curr_state.__hash__(), best_action)] = best_QV + ALPHA*(reward +\
                #                                         discount*max_reward - best_QV)
                for action in self.actions:
                    curr_QV = self.QV[(self.curr_state.__hash__(), action)]
                    reward = self.reward(self.curr_state, action)
                    max_reward = self.max_reward(self.curr_state, action)
                    self.QV[(self.curr_state.__hash__(), action)] = curr_QV + ALPHA*(reward +\
                                                         (discount**vc)*max_reward - curr_QV)
                print("new q value for " + best_action + " action is " + str(self.QV[(self.curr_state.__hash__(), best_action)]))
                self.curr_state.move(best_action)
                self.curr_state = self.curr_state.copy()
                if self.curr_state.isGoalState():
                    print("reached goal state while in Q-learning epsiode " + str(i))
                    #time.sleep(2)
                    return
                self.second_last_action = self.last_action  
                self.last_action = best_action
            else:
                # pick random move
                action = random.choice(self.actions)
                self.move[action] = self.move[action] + 1
                while action == self.last_action or action == self.second_last_action:
                    action = random.choice(self.actions)
                # update Q-Value for current state and randomly chosen action, by taking original Q-value, and adding
                # alpha times the reward value of the new state plus the discounted max_reward of executing every possible
                # action on the new state, minus the original Q-Value
                #reward = self.reward(self.curr_state, action)
                #max_reward = self.max_reward(self.curr_state, action)
                #print("max reward... " + str(max_reward))
                #print("reward... " + str(reward))
                #self.QV[(self.curr_state.__hash__(), action)] = curr_QV + ALPHA*(reward +\
                # discount*max_reward - curr_QV)
                reward = 0
                for action in self.actions:
                    curr_QV = self.QV[(self.curr_state.__hash__(), action)]
                    reward = self.reward(self.curr_state, action)
                    max_reward = self.max_reward(self.curr_state, action)
                    self.QV[(self.curr_state.__hash__(), action)] = curr_QV + ALPHA*(reward +\
                                                         (discount**vc)*max_reward - curr_QV)
                    
                #print(self.reward(self.curr_state,action))
                #print(self.QV[(self.curr_state,action)])
                self.curr_state.move(action)
                self.curr_state = self.curr_state.copy()
                self.second_last_action = self.last_action  
                self.last_action = action
                if self.curr_state.isGoalState():
                    print("reached goal state while in Q-learning epsiode " + str(i))
                    #time.sleep(2)
                    return

    def Play(self):
        self.second_last_action = None
        self.last_action = None
        self.curr_state = self.start_state
        print(self.curr_state)
        for i in range(20):
            best_action = None
            best_QV = -100000000
            if not (self.curr_state.__hash__(), self.actions[0]) in self.QV.keys():
                best_action = random.choice(self.actions)
                while best_action == self.second_last_action or best_action == self.last_action:
                    best_action = random.choice(self.actions)
                for action in self.actions:
                    self.QV[(self.curr_state.__hash__(), action)] = 0
                best_QV = 0
            else:
                for action in self.actions:
                    if self.QV[(self.curr_state.__hash__(), action)] > best_QV \
                    and (action != self.last_action and action != self.second_last_action):
                        best_action = action
                        best_QV = self.QV[(self.curr_state.__hash__(), action)]
                #if best_QV == 0:
                #    best_action = random.choice(self.actions)
                #    while best_action == self.last_action or best_action == self.second_last_action:
                #        best_action = random.choice(self.actions)
            print("actions chosen = " + best_action)
            print("last action = " + (self.last_action if self.last_action is not None  else "None"))
            print("q value is " + str(self.QV[(self.curr_state.__hash__(), best_action)]))
            #time.sleep(1)
            self.curr_state.move(best_action)
            self.second_last_action = self.last_action
            self.last_action = best_action
            print(self.curr_state)
            if self.curr_state.isGoalState():
                print("AGENT REACHED A GOAL STATE!!!")
                #time.sleep(5)
                return


    def print_(self):
        print("=============")
        x = 0
        y = 0
        for key in self.QV.keys():
            if self.QV[key] != 0:
                x += 1
            else:
                y += 1
        print("number of q values in dictionary is " + str(x + y))
        print("number of q values with zero value is " + str(y))
        print("number of q value with non zero value is " + str(x))
        print("number of re visited states = " + str(self.revisits))
        print(self.move)
            
    def reward(self, state, action):
        # this reward function should be a function approximation made up of
        # a set of features, these features should be in decreasing order of priority:
        # 1. solved sides ()
        # use next state to get value for next state vs. self.curr_state, to determine
        # if feature values should be 1 or 0, e.g. if solved_sides(next_state) > solved_sides(self.curr_state)
        # then the solved sides feature is 1, else 0
        next_state = move(state, action)
        if next_state.isGoalState():
            print(state)
            print(next_state)
            print("REWARD IS GOAL")
            return 100
        reward = -0.1
        solved_sides = 2 * (num_solved_sides(next_state) < num_solved_sides(state))
        solved_pieces = 0.5 * (num_pieces_correct_side(next_state) < num_pieces_correct_side(state))
        if (next_state.__hash__(), action) in self.QV.keys():
            reward -= 0.2
        reward -= solved_sides
        reward -= solved_pieces
        return reward

    def max_reward(self, state, action):
        new_state = move(state, action)
        if not new_state in self.R.keys():
            self.R[new_state] = []
            for action in self.actions:
                self.R[new_state].append(self.reward(new_state, action))
        return max(self.R[new_state])
    # execute Q-value iteration

    # run based on current policy

# %% [markdown]
# # 2. Het daadwerkelijk testen

# %%
agent = Agent()
print("REGISTERING PATTERN DATABASE, THIS WILL TAKE A LITTLE WHILE")
agent.register_patterns()
print(agent.QV)
Epsilons = [i/ 50 for i in range(50)]
Epsilons.reverse()
for i in range(2):
    for j, e in enumerate(Epsilons):
        print("======= ROUND " + str(j) + "=========")
        agent.QLearn(epsilon=e)
print("there are " + str(len(agent.QV)) + " keys in Q Table")
agent.Play()
agent.print_()
# Out:
# executing bottom 180 rotation
# executing right 180 rotation
# executing front 180 rotation
# executing back 180 rotation
# executing bottom 180 rotation
# executing left 180 rotation
#
# FRONT[['Y', 'Y', 'Y'], ['W', 'W', 'W'], ['W', 'Y', 'W']]
# BACK[['W', 'W', 'W'], ['Y', 'Y', 'Y'], ['Y', 'W', 'Y']]
# LEFT[['G', 'G', 'G'], ['G', 'B', 'G'], ['B', 'B', 'B']]
# RIGHT[['B', 'B', 'B'], ['B', 'G', 'B'], ['G', 'G', 'G']]
# TOP[['O', 'O', 'R'], ['O', 'R', 'R'], ['O', 'O', 'R']]
# BOTTOM[['R', 'R', 'O'], ['R', 'O', 'O'], ['R', 'R', 'O']]
# REGISTERING PATTERN DATABASE, THIS WILL TAKE A LITTLE WHILE
# {(5367153100357120408, 'front'): 3, (5367153100357120408, 'back'): -3, (5367153100357120408, 'left'): -3, (5367153100357120408, 'right'): -3, (5367153100357120408, 'top'): -3, (5367153100357120408, 'bottom'): -3, (7858836553087116078, 'front'): -3, (7858836553087116078, 'back'): 3, (7858836553087116078, 'left'): -3, (7858836553087116078, 'right'): -3, (7858836553087116078, 'top'): -3, (7858836553087116078, 'bottom'): -3, (7576104711465129911, 'front'): -3, (7576104711465129911, 'back'): -3, (7576104711465129911, 'left'): 3, (7576104711465129911, 'right'): -3, (7576104711465129911, 'top'): -3, (7576104711465129911, 'bottom'): -3, (-4533957737306501625, 'front'): -3, (-4533957737306501625, 'back'): -3, (-4533957737306501625, 'left'): -3, (-4533957737306501625, 'right'): 3, (-4533957737306501625, 'top'): -3, (-4533957737306501625, 'bottom'): -3, (6875852925815417666, 'front'): -3, (6875852925815417666, 'back'): -3, (6875852925815417666, 'left'): -3, (6875852925815417666, 'right'): -3, (6875852925815417666, 'top'): 3, (6875852925815417666, 'bottom'): -3, (-5675262259924449304, 'front'): -3, (-5675262259924449304, 'back'): -3, (-5675262259924449304, 'left'): -3, (-5675262259924449304, 'right'): -3, (-5675262259924449304, 'top'): -3, (-5675262259924449304, 'bottom'): 3, (-3664510428161455408, 'front'): -1, (-3664510428161455408, 'back'): -1, (-3664510428161455408, 'left'): -1, (-3664510428161455408, 'right'): -1, (-3664510428161455408, 'top'): -1, (-3664510428161455408, 'bottom'): 1, (-3933731611984194664, 'front'): 1, (-3933731611984194664, 'back'): -1, (-3933731611984194664, 'left'): -1, (-3933731611984194664, 'right'): -1, (-3933731611984194664, 'top'): -1, (-3933731611984194664, 'bottom'): -1, (-6666390602314815102, 'front'): -1, (-6666390602314815102, 'back'): -1, (-6666390602314815102, 'left'): 1, (-6666390602314815102, 'right'): -1, (-6666390602314815102, 'top'): -1, (-6666390602314815102, 'bottom'): -1, (-1443003479429092897, 'front'): -1, (-1443003479429092897, 'back'): -1, (-1443003479429092897, 'left'): -1, (-1443003479429092897, 'right'): 1, (-1443003479429092897, 'top'): -1, (-1443003479429092897, 'bottom'): -1, (-9157698033502752655, 'front'): -1, (-9157698033502752655, 'back'): -1, (-9157698033502752655, 'left'): -1, (-9157698033502752655, 'right'): -1, (-9157698033502752655, 'top'): 1, (-9157698033502752655, 'bottom'): -1, (746811127329659544, 'front'): -1, (746811127329659544, 'back'): -1, (746811127329659544, 'left'): -1, (746811127329659544, 'right'): -1, (746811127329659544, 'top'): -1, (746811127329659544, 'bottom'): 1, (-8843167847732699392, 'front'): -1, (-8843167847732699392, 'back'): -1, (-8843167847732699392, 'left'): 1, (-8843167847732699392, 'right'): -1, (-8843167847732699392, 'top'): -1, (-8843167847732699392, 'bottom'): -1, (4551704702052468538, 'front'): -1, (4551704702052468538, 'back'): -1, (4551704702052468538, 'left'): -1, (4551704702052468538, 'right'): 1, (4551704702052468538, 'top'): -1, (4551704702052468538, 'bottom'): -1, (-2427152044268807900, 'front'): -1, (-2427152044268807900, 'back'): -1, (-2427152044268807900, 'left'): -1, (-2427152044268807900, 'right'): -1, (-2427152044268807900, 'top'): 1, (-2427152044268807900, 'bottom'): -1, (-7999617310030887816, 'front'): -1, (-7999617310030887816, 'back'): -1, (-7999617310030887816, 'left'): -1, (-7999617310030887816, 'right'): -1, (-7999617310030887816, 'top'): -1, (-7999617310030887816, 'bottom'): 1, (48822888562269255, 'front'): 1, (48822888562269255, 'back'): -1, (48822888562269255, 'left'): -1, (48822888562269255, 'right'): -1, (48822888562269255, 'top'): -1, (48822888562269255, 'bottom'): -1, (-2659435546843248562, 'front'): -1, (-2659435546843248562, 'back'): 1, (-2659435546843248562, 'left'): -1, (-2659435546843248562, 'right'): -1, (-2659435546843248562, 'top'): -1, (-2659435546843248562, 'bottom'): -1, (1329200105412334572, 'front'): -1, (1329200105412334572, 'back'): -1, (1329200105412334572, 'left'): 1, (1329200105412334572, 'right') ...
# ======= ROUND 0=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.015710478202372147
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.6818692897954041
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.9371574489019121
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.5407327366686812
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.7249686973782787
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.18772933040791506
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.6724844928295506
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.5192937384179339
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.4134381103911112
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.8605556528651155
# ======= ROUND 1=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.06987614670853082
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.6137354775936251
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.8183725166792032
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.4177711747767111
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.4523382416704206
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.5701715206782525
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.5622564405919542
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.6731538726216937
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.4689210422236576
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.9495298580993706
# ======= ROUND 2=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.5557529290668041
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.9707012948835669
# FOLLOWING POLICY
# q value for action front from curr state is -0.1989791333376
# q value for action back from curr state is -0.1989791333376
# q value for action left from curr state is -0.6989267045376
# q value for action right from curr state is -0.1989791333376
# q value for action top from curr state is -0.3989581618176
# q value for action bottom from curr state is -0.3989581618176
# actions chosen = front
# new q value for front action is -0.19899165333504001
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.7772078229812559
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.17195028187840267
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.4168381175835736
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.5407888915371883
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.007046812060511942
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.5431929118505842
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.14594567776316303
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.001960743821535882
# ======= ROUND 3=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.42916814931939795
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.5030615451832963
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.5679861741798544
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.5578610911228358
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.024300153495893873
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.3595096202849998
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.509978774528156
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.24023478654822694
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.38058672739789745
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.06682856580600993
# ======= ROUND 4=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.2503742527133036
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.7926970214911904
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.6046596224670682
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.22978791824212053
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.07286919517615065
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.32012546823806043
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.035771082022389544
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.7960685178565523
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.9222818822168836
# FOLLOWING POLICY
# q value for action front from curr state is -0.8989939669131264
# q value for action back from curr state is -0.1989986645336064
# q value for action left from curr state is -0.6989953090904063
# q value for action right from curr state is -0.1989986645336064
# q value for action top from curr state is -0.1989986645336064
# q value for action bottom from curr state is -0.3989953090904064
# actions chosen = back
# new q value for back action is -0.19899946581344258
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.37540682440911977
# ======= ROUND 5=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.29993678502247356
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.11413052227097209
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.7687964501173845
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.02263870434741133
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.9376619934681366
# FOLLOWING POLICY
# q value for action front from curr state is -0.5871599999999999
# q value for action back from curr state is -0.5871599999999999
# q value for action left from curr state is -0.75348
# q value for action right from curr state is -0.75348
# q value for action top from curr state is -0.16716
# q value for action bottom from curr state is -0.75516
# actions chosen = top
# new q value for top action is -0.186264
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.449911977680995
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.6937057988229315
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.15655548395278185
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.4606812066315181
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.6007060439254388
# ======= ROUND 6=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.7452910137078534
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.6024052894971127
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.7119185836141081
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.5393847886764119
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.7108127555928802
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.8176901305326295
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.06208112253253817
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.7964812476979499
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.6202392513378042
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.20579223726172402
# ======= ROUND 7=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.5376449644600098
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.21268861894036417
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.551407168178975
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.09607116654640424
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.43543164204241847
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.8171562002230498
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.8469040903237391
# FOLLOWING POLICY
# q value for action front from curr state is -0.6989267045376
# q value for action back from curr state is -0.6989267045376
# q value for action left from curr state is -0.6989267045376
# q value for action right from curr state is -0.6989267045376
# q value for action top from curr state is -0.3989581618176
# q value for action bottom from curr state is -0.3989581618176
# actions chosen = top
# new q value for top action is -0.39898326472704004
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.14016179233835258
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.7862112793551121
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.9725440765664001
# FOLLOWING POLICY
# q value for action front from curr state is -0.6811056
# q value for action back from curr state is -0.8759856
# q value for action left from curr state is -0.6811056
# q value for action right from curr state is -0.1939056
# q value for action top from curr state is -0.4327056
# q value for action bottom from curr state is -0.49990560000000006
# actions chosen = right
# new q value for right action is -0.19696224
# ======= ROUND 8=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.46840437442251204
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.7442538046915991
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.3366683551486257
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.8010435944415722
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.23841676580374105
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.17669025272692385
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.8186833791436379
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.8467938469846729
# FOLLOWING POLICY
# q value for action front from curr state is -2.5262640000000003
# q value for action back from curr state is -2.5262640000000003
# q value for action left from curr state is -2.7115920000000004
# q value for action right from curr state is -2.5262640000000003
# q value for action top from curr state is -0.654264
# q value for action bottom from curr state is -0.5587920000000001
# actions chosen = top
# new q value for top action is -0.6811056
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.935217265859158
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -1.6194000000000002
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.6851658891842906
# ======= ROUND 9=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.7925466682309161
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.1805093867544596
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.7874304032511329
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.8211620070510364
# FOLLOWING POLICY
# q value for action front from curr state is -0.16716
# q value for action back from curr state is -0.16716
# q value for action left from curr state is -0.33516
# q value for action right from curr state is -0.5871599999999999
# q value for action top from curr state is -0.16716
# q value for action bottom from curr state is -0.70716
# actions chosen = front
# new q value for front action is -0.186264
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.5365969054403372
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.5449143920985967
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.4557648858834694
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.12713532241681758
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.8796207080440437
# FOLLOWING POLICY
# q value for action front from curr state is -0.33516
# q value for action back from curr state is -0.16716
# q value for action left from curr state is -0.5829599999999999
# q value for action right from curr state is -0.5871599999999999
# q value for action top from curr state is -0.5871599999999999
# q value for action bottom from curr state is -0.70716
# actions chosen = back
# new q value for back action is -0.186264
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.9122211004729646
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = front
# new q value for front action is -0.1194
# ======= ROUND 10=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.6160812427107802
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.8399882844518822
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -0.1194
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.9365594413198451
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = back
# new q value for back action is -0.1194
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.6732551098697287
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.18171135842784336
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.28613051851624416
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.4393042771282786
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.7036184925980044
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.35019909686708317
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.8848177345963361
# FOLLOWING POLICY
# q value for action front from curr state is -0.186264
# q value for action back from curr state is -0.373464
# q value for action left from curr state is -0.186264
# q value for action right from curr state is -0.186264
# q value for action top from curr state is -0.186264
# q value for action bottom from curr state is -0.822264
# actions chosen = front
# new q value for front action is -0.1939056
# ======= ROUND 11=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.3888325313076697
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.5513723758866219
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.2357113156376781
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.971327355217585
# FOLLOWING POLICY
# q value for action front from curr state is -0.41939999999999994
# q value for action back from curr state is -0.1194
# q value for action left from curr state is -0.1194
# q value for action right from curr state is -0.1194
# q value for action top from curr state is -0.1194
# q value for action bottom from curr state is -0.2394
# actions chosen = back
# new q value for back action is -0.16716
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.28705721762352876
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.2511058944902783
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.7421830616850509
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.8494955262188281
# FOLLOWING POLICY
# q value for action front from curr state is -0.41939999999999994
# q value for action back from curr state is -0.41939999999999994
# q value for action left from curr state is -0.1194
# q value for action right from curr state is -0.1194
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.2394
# actions chosen = left
# new q value for left action is -0.16716
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.002771506989881267
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.5503944513864459
# ======= ROUND 12=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.5683424180266723
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.7553290903214693
# FOLLOWING POLICY
# q value for action front from curr state is -0.41939999999999994
# q value for action back from curr state is -0.2382
# q value for action left from curr state is -0.41939999999999994
# q value for action right from curr state is -0.41939999999999994
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.5394
# actions chosen = back
# new q value for back action is -0.33348
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.3755513268502758
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.0723198887008325
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.3290291940322905
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.7513666811748048
# FOLLOWING POLICY
# q value for action front from curr state is -0.41939999999999994
# q value for action back from curr state is -0.41939999999999994
# q value for action left from curr state is -0.1194
# q value for action right from curr state is -0.41939999999999994
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.3582
# actions chosen = left
# new q value for left action is -0.16716
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.4526992512450666
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.49449403244577605
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.36475481738476645
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.006750611976992005
# ======= ROUND 13=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.4538207896357035
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.3606951975359739
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.9830529837381535
# FOLLOWING POLICY
# q value for action front from curr state is -0.654264
# q value for action back from curr state is -0.654264
# q value for action left from curr state is -1.026792
# q value for action right from curr state is -0.654264
# q value for action top from curr state is -0.654264
# q value for action bottom from curr state is -0.354264
# actions chosen = front
# new q value for front action is -0.6811056
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.8540606455501824
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = top
# new q value for top action is -0.1194
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.8021558943553788
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.1194
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.7642265285732871
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = back
# new q value for back action is -0.41939999999999994
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.4708552764744788
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.9664913380166853
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -0.41939999999999994
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.6117267477393773
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.15507460666559725
# ======= ROUND 14=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.8591550206465328
# FOLLOWING POLICY
# q value for action front from curr state is -0.1194
# q value for action back from curr state is -0.41939999999999994
# q value for action left from curr state is -0.2394
# q value for action right from curr state is -0.41939999999999994
# q value for action top from curr state is -0.1194
# q value for action bottom from curr state is -0.1194
# actions chosen = front
# new q value for front action is -0.16716
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.12319626011165086
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.08947889146093291
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.9137743793867914
# FOLLOWING POLICY
# q value for action front from curr state is -0.5394
# q value for action back from curr state is -0.41939999999999994
# q value for action left from curr state is -0.1194
# q value for action right from curr state is -0.41939999999999994
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.41639999999999994
# actions chosen = left
# new q value for left action is -0.16716
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.7900449117295014
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = bottom
# new q value for bottom action is -0.41939999999999994
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.5746082373020327
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.5858746886499765
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.5228086662697197
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.21149580036211646
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.2986949766320177
# ======= ROUND 15=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.10667174602209817
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.07397420520543196
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.8043531503110434
# FOLLOWING POLICY
# q value for action front from curr state is -0.6811056
# q value for action back from curr state is -0.1939056
# q value for action left from curr state is -0.5817168
# q value for action right from curr state is -0.6811056
# q value for action top from curr state is -0.6811056
# q value for action bottom from curr state is -0.8683056
# actions chosen = back
# new q value for back action is -0.19696224
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.8418678101070837
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = bottom
# new q value for bottom action is -0.1194
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.6052468106481058
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.3473519169415885
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.41855379879781884
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.804601204444031
# FOLLOWING POLICY
# q value for action front from curr state is -0.5871599999999999
# q value for action back from curr state is -0.50148
# q value for action left from curr state is -0.16716
# q value for action right from curr state is -0.5871599999999999
# q value for action top from curr state is -0.16716
# q value for action bottom from curr state is -0.28715999999999997
# actions chosen = left
# new q value for left action is -0.186264
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.4480385932374824
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.6677618181535326
# ======= ROUND 16=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.5196394508318698
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.6144819478060067
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.5316253732850679
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.11102525443081257
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.6094965530032728
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.4864012469153808
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.5020404671738817
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.6804246022134458
# FOLLOWING POLICY
# q value for action front from curr state is -0.6811056
# q value for action back from curr state is -0.6811056
# q value for action left from curr state is -0.6811056
# q value for action right from curr state is -0.6811056
# q value for action top from curr state is -0.38683680000000004
# q value for action bottom from curr state is -0.8759856
# actions chosen = top
# new q value for top action is -0.39293472
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.44012302853827867
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.5445190848580195
# ======= ROUND 17=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.46146280170254017
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.019753144293337077
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.041018165487138436
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.6856620001818671
# FOLLOWING POLICY
# q value for action front from curr state is -0.5871599999999999
# q value for action back from curr state is -0.5871599999999999
# q value for action left from curr state is -0.16716
# q value for action right from curr state is -0.5871599999999999
# q value for action top from curr state is -0.50148
# q value for action bottom from curr state is -0.50148
# actions chosen = left
# new q value for left action is -0.186264
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.30098075868352725
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.6344930019810402
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.3307344657648196
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.009650175565152463
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.4663189454228548
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.8614992078613317
# FOLLOWING POLICY
# q value for action front from curr state is -0.16716
# q value for action back from curr state is -0.5871599999999999
# q value for action left from curr state is -0.5871599999999999
# q value for action right from curr state is -0.5829599999999999
# q value for action top from curr state is -0.5871599999999999
# q value for action bottom from curr state is -0.33516
# actions chosen = front
# new q value for front action is -0.186264
# ======= ROUND 18=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.4821779181710095
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.4576696058438383
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.23578110037140354
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.8382691636214209
# FOLLOWING POLICY
# q value for action front from curr state is -0.1194
# q value for action back from curr state is -0.1194
# q value for action left from curr state is -0.41939999999999994
# q value for action right from curr state is -0.41939999999999994
# q value for action top from curr state is -0.1194
# q value for action bottom from curr state is -0.2394
# actions chosen = front
# new q value for front action is -0.16716
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.9337601633089685
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = back
# new q value for back action is -0.41639999999999994
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.4747552234893053
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.24998601745067994
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.7725255174327463
# FOLLOWING POLICY
# q value for action front from curr state is -0.41939999999999994
# q value for action back from curr state is -0.5394
# q value for action left from curr state is -0.5382
# q value for action right from curr state is -0.5382
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.41939999999999994
# actions chosen = front
# new q value for front action is -0.5871599999999999
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.4683445946052641
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.5439506911893262
# ======= ROUND 19=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.22726226394018378
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.511627954326123
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.3540161137299439
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.3486182477312003
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.68045507697279
# FOLLOWING POLICY
# q value for action front from curr state is -0.836784
# q value for action back from curr state is -0.841464
# q value for action left from curr state is -0.654264
# q value for action right from curr state is -0.654264
# q value for action top from curr state is -0.186264
# q value for action bottom from curr state is -0.822264
# actions chosen = top
# new q value for top action is -0.1939056
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.16450085666165082
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.725659879169206
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = back
# new q value for back action is -0.41639999999999994
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.9220243608556244
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.5382
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.3446637570325295
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.15651502502965364
# ======= ROUND 20=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.9373711914059419
# FOLLOWING POLICY
# q value for action front from curr state is -0.41939999999999994
# q value for action back from curr state is -0.41939999999999994
# q value for action left from curr state is -0.41939999999999994
# q value for action right from curr state is -0.5364
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.41939999999999994
# actions chosen = front
# new q value for front action is -0.5871599999999999
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.41911713283619345
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.33999002240527054
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.10996399888294706
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.5764441690679118
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.32332594243824075
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.9312948086696932
# FOLLOWING POLICY
# q value for action front from curr state is -0.16716
# q value for action back from curr state is -0.5871599999999999
# q value for action left from curr state is -0.16716
# q value for action right from curr state is -0.5871599999999999
# q value for action top from curr state is -0.16716
# q value for action bottom from curr state is -0.33516
# actions chosen = front
# new q value for front action is -0.186264
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.1441168629504871
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.6773707325620494
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.41939999999999994
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.26707436573975507
# ======= ROUND 21=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.7995555901808461
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.41939999999999994
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.4544768477608194
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.8809845519879662
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = top
# new q value for top action is -0.1194
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.9578742842582539
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = front
# new q value for front action is -0.1194
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.36245192942277016
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.1963321641854544
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.7916361128586823
# FOLLOWING POLICY
# q value for action front from curr state is -0.2394
# q value for action back from curr state is -0.1194
# q value for action left from curr state is -0.1194
# q value for action right from curr state is -0.1194
# q value for action top from curr state is -0.41939999999999994
# q value for action bottom from curr state is -0.1194
# actions chosen = back
# new q value for back action is -0.16716
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.008049080318364266
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.8612158519096881
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.1194
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.9179124041159207
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = bottom
# new q value for bottom action is -0.1194
# ======= ROUND 22=========
# ...
# q value for action left from curr state is -1
# q value for action right from curr state is -1
# q value for action top from curr state is -1
# q value for action bottom from curr state is -1
# actions chosen = left
# new q value for left action is -0.7582000000000001
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.42447316840414984
# FOLLOWING POLICY
# q value for action front from curr state is -3
# q value for action back from curr state is -3
# q value for action left from curr state is 3
# q value for action right from curr state is -3
# q value for action top from curr state is -3
# q value for action bottom from curr state is -3
# actions chosen = front
# new q value for front action is -1.4394
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.6923334664989231
# FOLLOWING POLICY
# q value for action front from curr state is 1
# q value for action back from curr state is -1
# q value for action left from curr state is -1
# q value for action right from curr state is -1
# q value for action top from curr state is -1
# q value for action bottom from curr state is -1
# actions chosen = back
# new q value for back action is -0.5194000000000001
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.28695411599861076
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -0.1194
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.5267785502880572
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.1194
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.15848786821299965
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -0.1194
# ======= ROUND 49=========
# =====EPISODE 0=====
# ====CURR STATE========
# ======================
# random value generated is 0.6577936962785792
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = top
# new q value for top action is -0.2382
# =====EPISODE 1=====
# ====CURR STATE========
# ======================
# random value generated is 0.5668002839300531
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -0.41939999999999994
# =====EPISODE 2=====
# ====CURR STATE========
# ======================
# random value generated is 0.34376942030489144
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = right
# new q value for right action is -0.41939999999999994
# =====EPISODE 3=====
# ====CURR STATE========
# ======================
# random value generated is 0.25743159697596385
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = bottom
# new q value for bottom action is -0.41939999999999994
# =====EPISODE 4=====
# ====CURR STATE========
# ======================
# random value generated is 0.3431826494971092
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = left
# new q value for left action is -0.1194
# =====EPISODE 5=====
# ====CURR STATE========
# ======================
# random value generated is 0.677889161228837
# FOLLOWING POLICY
# q value for action front from curr state is 0
# q value for action back from curr state is 0
# q value for action left from curr state is 0
# q value for action right from curr state is 0
# q value for action top from curr state is 0
# q value for action bottom from curr state is 0
# actions chosen = top
# new q value for top action is -0.2394
# =====EPISODE 6=====
# ====CURR STATE========
# ======================
# random value generated is 0.4143954107198562
# FOLLOWING POLICY
# q value for action front from curr state is 1
# q value for action back from curr state is -1
# q value for action left from curr state is -1
# q value for action right from curr state is -1
# q value for action top from curr state is -1
# q value for action bottom from curr state is -1
# actions chosen = front
# new q value for front action is -0.2582
# =====EPISODE 7=====
# ====CURR STATE========
# ======================
# random value generated is 0.97543234812723
# FOLLOWING POLICY
# q value for action front from curr state is -3
# q value for action back from curr state is 3
# q value for action left from curr state is -3
# q value for action right from curr state is -3
# q value for action top from curr state is -3
# q value for action bottom from curr state is -3
# actions chosen = back
# new q value for back action is 0.5418000000000003
# =====EPISODE 8=====
# ====CURR STATE========
# ======================
# random value generated is 0.920943136781587
# FOLLOWING POLICY
# q value for action front from curr state is -1
# q value for action back from curr state is -1
# q value for action left from curr state is -1
# q value for action right from curr state is -1
# q value for action top from curr state is -1
# q value for action bottom from curr state is 1
# actions chosen = bottom
# new q value for bottom action is 0.04180000000000006
# =====EPISODE 9=====
# ====CURR STATE========
# ======================
# random value generated is 0.209352669244394
# FOLLOWING POLICY
# q value for action front from curr state is 3
# q value for action back from curr state is -3
# q value for action left from curr state is -3
# q value for action right from curr state is -3
# q value for action top from curr state is -3
# q value for action bottom from curr state is -3
# actions chosen = front
# new q value for front action is 0.8418000000000001
# there are 65214 keys in Q Table
#
# FRONT[['Y', 'Y', 'Y'], ['W', 'W', 'W'], ['Y', 'W', 'Y']]
# BACK[['W', 'W', 'W'], ['Y', 'Y', 'Y'], ['W', 'Y', 'W']]
# LEFT[['G', 'G', 'G'], ['G', 'B', 'G'], ['G', 'G', 'G']]
# RIGHT[['B', 'B', 'B'], ['B', 'G', 'B'], ['B', 'B', 'B']]
# TOP[['O', 'O', 'R'], ['O', 'R', 'R'], ['O', 'O', 'R']]
# BOTTOM[['O', 'R', 'R'], ['O', 'O', 'R'], ['O', 'R', 'R']]
# actions chosen = front
# last action = None
# q value is -0.19899165333504001
#
# FRONT[['Y', 'W', 'Y'], ['W', 'W', 'W'], ['Y', 'Y', 'Y']]
# BACK[['W', 'W', 'W'], ['Y', 'Y', 'Y'], ['W', 'Y', 'W']]
# LEFT[['G', 'G', 'B'], ['G', 'B', 'B'], ['G', 'G', 'B']]
# RIGHT[['G', 'B', 'B'], ['G', 'G', 'B'], ['G', 'B', 'B']]
# TOP[['O', 'R', 'R'], ['O', 'R', 'R'], ['O', 'O', 'R']]
# BOTTOM[['O', 'O', 'R'], ['O', 'O', 'R'], ['O', 'R', 'R']]
# actions chosen = back
# last action = front
# q value is -0.19899946581344258
#
# FRONT[['Y', 'W', 'Y'], ['W', 'W', 'W'], ['Y', 'Y', 'Y']]
# BACK[['W', 'Y', 'W'], ['Y', 'Y', 'Y'], ['W', 'W', 'W']]
# LEFT[['B', 'G', 'B'], ['B', 'B', 'B'], ['B', 'G', 'B']]
# RIGHT[['G', 'B', 'G'], ['G', 'G', 'G'], ['G', 'B', 'G']]
# TOP[['O', 'R', 'R'], ['O', 'R', 'R'], ['O', 'R', 'R']]
# BOTTOM[['O', 'O', 'R'], ['O', 'O', 'R'], ['O', 'O', 'R']]
# actions chosen = right
# last action = back
# q value is -0.19696224
#
# FRONT[['Y', 'W', 'W'], ['W', 'W', 'Y'], ['Y', 'Y', 'W']]
# BACK[['Y', 'Y', 'W'], ['W', 'Y', 'Y'], ['Y', 'W', 'W']]
# LEFT[['B', 'G', 'B'], ['B', 'B', 'B'], ['B', 'G', 'B']]
# RIGHT[['G', 'B', 'G'], ['G', 'G', 'G'], ['G', 'B', 'G']]
# TOP[['R', 'R', 'R'], ['R', 'R', 'R'], ['R', 'R', 'R']]
# BOTTOM[['O', 'O', 'O'], ['O', 'O', 'O'], ['O', 'O', 'O']]
# actions chosen = bottom
# last action = right
# q value is -0.5740368000000001
#
# FRONT[['Y', 'W', 'W'], ['W', 'W', 'Y'], ['Y', 'W', 'W']]
# BACK[['Y', 'Y', 'W'], ['W', 'Y', 'Y'], ['Y', 'Y', 'W']]
# LEFT[['B', 'G', 'B'], ['B', 'B', 'B'], ['G', 'B', 'G']]
# RIGHT[['G', 'B', 'G'], ['G', 'G', 'G'], ['B', 'G', 'B']]
# TOP[['R', 'R', 'R'], ['R', 'R', 'R'], ['R', 'R', 'R']]
# BOTTOM[['O', 'O', 'O'], ['O', 'O', 'O'], ['O', 'O', 'O']]
# actions chosen = top
# last action = bottom
# q value is -0.6811056
#
# FRONT[['Y', 'Y', 'W'], ['W', 'W', 'Y'], ['Y', 'W', 'W']]
# BACK[['Y', 'W', 'W'], ['W', 'Y', 'Y'], ['Y', 'Y', 'W']]
# LEFT[['G', 'B', 'G'], ['B', 'B', 'B'], ['G', 'B', 'G']]
# RIGHT[['B', 'G', 'B'], ['G', 'G', 'G'], ['B', 'G', 'B']]
# TOP[['R', 'R', 'R'], ['R', 'R', 'R'], ['R', 'R', 'R']]
# BOTTOM[['O', 'O', 'O'], ['O', 'O', 'O'], ['O', 'O', 'O']]
# actions chosen = left
# last action = top
# q value is -1.6194000000000002
#
# FRONT[['W', 'Y', 'W'], ['Y', 'W', 'Y'], ['W', 'W', 'W']]
# BACK[['Y', 'W', 'Y'], ['W', 'Y', 'W'], ['Y', 'Y', 'Y']]
# LEFT[['G', 'B', 'G'], ['B', 'B', 'B'], ['G', 'B', 'G']]
# RIGHT[['B', 'G', 'B'], ['G', 'G', 'G'], ['B', 'G', 'B']]
# TOP[['R', 'R', 'O'], ['R', 'R', 'O'], ['R', 'R', 'O']]
# BOTTOM[['R', 'O', 'O'], ['R', 'O', 'O'], ['R', 'O', 'O']]
# actions chosen = front
# last action = left
# q value is -0.186264
#
# FRONT[['W', 'W', 'W'], ['Y', 'W', 'Y'], ['W', 'Y', 'W']]
# BACK[['Y', 'W', 'Y'], ['W', 'Y', 'W'], ['Y', 'Y', 'Y']]
# LEFT[['G', 'B', 'B'], ['B', 'B', 'G'], ['G', 'B', 'B']]
# RIGHT[['G', 'G', 'B'], ['B', 'G', 'G'], ['G', 'G', 'B']]
# TOP[['R', 'O', 'O'], ['R', 'R', 'O'], ['R', 'R', 'O']]
# BOTTOM[['R', 'R', 'O'], ['R', 'O', 'O'], ['R', 'O', 'O']]
# actions chosen = back
# last action = front
# q value is -0.186264
#
# FRONT[['W', 'W', 'W'], ['Y', 'W', 'Y'], ['W', 'Y', 'W']]
# BACK[['Y', 'Y', 'Y'], ['W', 'Y', 'W'], ['Y', 'W', 'Y']]
# LEFT[['B', 'B', 'B'], ['G', 'B', 'G'], ['B', 'B', 'B']]
# RIGHT[['G', 'G', 'G'], ['B', 'G', 'B'], ['G', 'G', 'G']]
# TOP[['R', 'O', 'O'], ['R', 'R', 'O'], ['R', 'O', 'O']]
# BOTTOM[['R', 'R', 'O'], ['R', 'O', 'O'], ['R', 'R', 'O']]
# actions chosen = left
# last action = back
# q value is -0.41639999999999994
#
# FRONT[['Y', 'W', 'W'], ['W', 'W', 'Y'], ['Y', 'Y', 'W']]
# BACK[['Y', 'Y', 'W'], ['W', 'Y', 'Y'], ['Y', 'W', 'W']]
# LEFT[['B', 'B', 'B'], ['G', 'B', 'G'], ['B', 'B', 'B']]
# RIGHT[['G', 'G', 'G'], ['B', 'G', 'B'], ['G', 'G', 'G']]
# TOP[['R', 'O', 'R'], ['R', 'R', 'R'], ['R', 'O', 'R']]
# BOTTOM[['O', 'R', 'O'], ['O', 'O', 'O'], ['O', 'R', 'O']]
# actions chosen = top
# last action = left
# q value is 0
#
# FRONT[['Y', 'Y', 'W'], ['W', 'W', 'Y'], ['Y', 'Y', 'W']]
# BACK[['Y', 'W', 'W'], ['W', 'Y', 'Y'], ['Y', 'W', 'W']]
# LEFT[['G', 'G', 'G'], ['G', 'B', 'G'], ['B', 'B', 'B']]
# RIGHT[['B', 'B', 'B'], ['B', 'G', 'B'], ['G', 'G', 'G']]
# TOP[['R', 'O', 'R'], ['R', 'R', 'R'], ['R', 'O', 'R']]
# BOTTOM[['O', 'R', 'O'], ['O', 'O', 'O'], ['O', 'R', 'O']]
# actions chosen = front
# last action = top
# q value is 0
#
# FRONT[['W', 'Y', 'Y'], ['Y', 'W', 'W'], ['W', 'Y', 'Y']]
# BACK[['Y', 'W', 'W'], ['W', 'Y', 'Y'], ['Y', 'W', 'W']]
# LEFT[['G', 'G', 'B'], ['G', 'B', 'B'], ['B', 'B', 'G']]
# RIGHT[['G', 'B', 'B'], ['G', 'G', 'B'], ['B', 'G', 'G']]
# TOP[['O', 'R', 'O'], ['R', 'R', 'R'], ['R', 'O', 'R']]
# BOTTOM[['R', 'O', 'R'], ['O', 'O', 'O'], ['O', 'R', 'O']]
# actions chosen = right
# last action = front
# q value is 0
#
# FRONT[['W', 'Y', 'Y'], ['Y', 'W', 'W'], ['W', 'Y', 'Y']]
# BACK[['Y', 'W', 'W'], ['W', 'Y', 'Y'], ['Y', 'W', 'W']]
# LEFT[['G', 'G', 'B'], ['G', 'B', 'B'], ['B', 'B', 'G']]
# RIGHT[['G', 'G', 'B'], ['B', 'G', 'G'], ['B', 'B', 'G']]
# TOP[['O', 'R', 'O'], ['O', 'R', 'R'], ['R', 'O', 'R']]
# BOTTOM[['R', 'O', 'R'], ['O', 'O', 'R'], ['O', 'R', 'O']]
# actions chosen = back
# last action = right
# q value is 0
#
# FRONT[['W', 'Y', 'Y'], ['Y', 'W', 'W'], ['W', 'Y', 'Y']]
# BACK[['W', 'W', 'Y'], ['Y', 'Y', 'W'], ['W', 'W', 'Y']]
# LEFT[['B', 'G', 'B'], ['G', 'B', 'B'], ['G', 'B', 'G']]
# RIGHT[['G', 'G', 'G'], ['B', 'G', 'G'], ['B', 'B', 'B']]
# TOP[['O', 'R', 'O'], ['O', 'R', 'R'], ['O', 'R', 'O']]
# BOTTOM[['R', 'O', 'R'], ['O', 'O', 'R'], ['R', 'O', 'R']]
# actions chosen = bottom
# last action = back
# q value is 0
#
# FRONT[['W', 'Y', 'Y'], ['Y', 'W', 'W'], ['W', 'W', 'Y']]
# BACK[['W', 'W', 'Y'], ['Y', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['B', 'G', 'B'], ['G', 'B', 'B'], ['B', 'B', 'B']]
# RIGHT[['G', 'G', 'G'], ['B', 'G', 'G'], ['G', 'B', 'G']]
# TOP[['O', 'R', 'O'], ['O', 'R', 'R'], ['O', 'R', 'O']]
# BOTTOM[['R', 'O', 'R'], ['R', 'O', 'O'], ['R', 'O', 'R']]
# actions chosen = top
# last action = bottom
# q value is 0
#
# FRONT[['W', 'W', 'Y'], ['Y', 'W', 'W'], ['W', 'W', 'Y']]
# BACK[['W', 'Y', 'Y'], ['Y', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['G', 'G', 'G'], ['G', 'B', 'B'], ['B', 'B', 'B']]
# RIGHT[['B', 'G', 'B'], ['B', 'G', 'G'], ['G', 'B', 'G']]
# TOP[['O', 'R', 'O'], ['R', 'R', 'O'], ['O', 'R', 'O']]
# BOTTOM[['R', 'O', 'R'], ['R', 'O', 'O'], ['R', 'O', 'R']]
# actions chosen = front
# last action = top
# q value is 0
#
# FRONT[['Y', 'W', 'W'], ['W', 'W', 'Y'], ['Y', 'W', 'W']]
# BACK[['W', 'Y', 'Y'], ['Y', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['G', 'G', 'B'], ['G', 'B', 'B'], ['B', 'B', 'G']]
# RIGHT[['G', 'G', 'B'], ['B', 'G', 'G'], ['B', 'B', 'G']]
# TOP[['R', 'O', 'R'], ['R', 'R', 'O'], ['O', 'R', 'O']]
# BOTTOM[['O', 'R', 'O'], ['R', 'O', 'O'], ['R', 'O', 'R']]
# actions chosen = left
# last action = front
# q value is 0
#
# FRONT[['Y', 'W', 'W'], ['W', 'W', 'Y'], ['Y', 'W', 'W']]
# BACK[['W', 'Y', 'Y'], ['Y', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['G', 'B', 'B'], ['B', 'B', 'G'], ['B', 'G', 'G']]
# RIGHT[['G', 'G', 'B'], ['B', 'G', 'G'], ['B', 'B', 'G']]
# TOP[['R', 'O', 'R'], ['R', 'R', 'R'], ['O', 'R', 'O']]
# BOTTOM[['O', 'R', 'O'], ['O', 'O', 'O'], ['R', 'O', 'R']]
# actions chosen = top
# last action = left
# q value is 0
#
# FRONT[['W', 'Y', 'Y'], ['W', 'W', 'Y'], ['Y', 'W', 'W']]
# BACK[['Y', 'W', 'W'], ['Y', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['B', 'G', 'G'], ['B', 'B', 'G'], ['B', 'G', 'G']]
# RIGHT[['B', 'B', 'G'], ['B', 'G', 'G'], ['B', 'B', 'G']]
# TOP[['O', 'R', 'O'], ['R', 'R', 'R'], ['R', 'O', 'R']]
# BOTTOM[['O', 'R', 'O'], ['O', 'O', 'O'], ['R', 'O', 'R']]
# actions chosen = front
# last action = top
# q value is 0
#
# FRONT[['W', 'W', 'Y'], ['Y', 'W', 'W'], ['Y', 'Y', 'W']]
# BACK[['Y', 'W', 'W'], ['Y', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['B', 'G', 'B'], ['B', 'B', 'B'], ['B', 'G', 'B']]
# RIGHT[['G', 'B', 'G'], ['G', 'G', 'G'], ['G', 'B', 'G']]
# TOP[['O', 'R', 'O'], ['R', 'R', 'R'], ['R', 'O', 'R']]
# BOTTOM[['O', 'R', 'O'], ['O', 'O', 'O'], ['R', 'O', 'R']]
# actions chosen = right
# last action = front
# q value is 0
#
# FRONT[['W', 'W', 'Y'], ['Y', 'W', 'Y'], ['Y', 'Y', 'W']]
# BACK[['Y', 'W', 'W'], ['W', 'Y', 'W'], ['W', 'Y', 'Y']]
# LEFT[['B', 'G', 'B'], ['B', 'B', 'B'], ['B', 'G', 'B']]
# RIGHT[['G', 'B', 'G'], ['G', 'G', 'G'], ['G', 'B', 'G']]
# TOP[['R', 'R', 'O'], ['O', 'R', 'R'], ['O', 'O', 'R']]
# BOTTOM[['O', 'R', 'R'], ['O', 'O', 'R'], ['R', 'O', 'O']]
# =============
# number of q values in dictionary is 65280
# number of q values with zero value is 66
# number of q value with non zero value is 65214
# number of re visited states = 399
# {'front': 194, 'back': 172, 'left': 162, 'right': 166, 'top': 163, 'bottom': 137}
